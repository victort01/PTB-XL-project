# %% [markdown]
# # 03 - Extracao de features
#
# **Objetivo:** extrair estatisticas simples por derivacao para os modelos classicos.
#
# A extracao bruta usa apenas cada sinal individual. Imputacao, normalizacao e SMOTE acontecem depois, dentro dos pipelines ajustados no treino.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve()
if str(PROJECT_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT / 'src'))

from tcc_ecg.config import load_config
from tcc_ecg.data import prepare_metadata
from tcc_ecg.features import build_feature_table, get_feature_columns

config = load_config()
metadata = prepare_metadata(config, save_summary=True)
features, labels = build_feature_table(metadata, config, save=True)

print('Features:', features.shape)
print('Labels:', labels.shape)
print('Numero de colunas de entrada:', len(get_feature_columns(features)))
display(features.head())
# Out:
# Features: (16244, 151)
# Labels: (16244, 4)
# Numero de colunas de entrada: 147
#      I_mean     I_std  I_min  I_max  I_median    I_p25    I_p75  I_ptp  \
# 0  0.002609  0.111532 -0.240  0.690    -0.010 -0.05025  0.03500  0.930
# 1 -0.003573  0.130397 -0.419  0.686    -0.044 -0.08000  0.02525  1.105
# 2 -0.002780  0.121845 -0.160  0.870    -0.039 -0.06300  0.00700  1.030
# 3 -0.001062  0.137123 -0.625  0.530    -0.026 -0.05900  0.03000  1.155
# 4 -0.003599  0.083252 -0.285  0.500    -0.022 -0.04625  0.01300  0.785
#
#     I_energy     I_rms  ...    V6_rms   V6_skew  V6_kurtosis  age_clean  \
# 0  62.230951  0.111562  ...  0.103172  1.789248     4.822703       56.0
# 1  85.081125  0.130446  ...  0.179950  4.355631    26.681197       19.0
# 2  74.269690  0.121877  ...  0.101454  3.086953    15.452345       37.0
# 3  94.018682  0.137127  ...  0.337776  2.319224     7.586337       24.0
# 4  34.719205  0.083330  ...  0.180253  4.082063    20.790384       19.0
#
# ...
